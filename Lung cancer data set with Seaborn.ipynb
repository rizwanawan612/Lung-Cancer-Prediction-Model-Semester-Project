# %%
# Import the dependencies
# Ignore warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# %matplotlib inline

# %%
# Import seaborn

import seaborn as sns

# %%
# loading dataset
df=pd.read_csv("D:/survey lung cancer1.csv")
#df=data.copy()
df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  Level
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    int64
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
# Set the plot styles with set() method
sns.set_style("white")
sns.set()

# %%
sns.distplot(df['AGE']) 
plt.show()

# %%
sns.distplot(df['SMOKING']) 
plt.show()

# %%
sns.distplot(df['YELLOW_FINGERS']) 
plt.show()

# %%
sns.distplot(df['ANXIETY']) 
plt.show()

# %%
sns.lineplot(data=df,x='AGE', y='YELLOW_FINGERS', style='Level', lw=10, color='red', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='YELLOW_FINGERS'>

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'Level'],
#       dtype='object')

# %%
sns.distplot(df['COUGHING']) 
plt.show()

# %%
sns.distplot(df['COUGHING'], color='green', kde=True) 

plt.show()

# %%
#In seaborn, the hue parameter determines which column in the data frame should be used for colour encoding
sns.set_style('white')
sns.relplot(x='AGE',y='COUGHING', data=df, kind='line' , hue='Level', col='GENDER')

# %%
#sns.distplot(tips['cholesterol'])
#shade, Bw, 
sns.kdeplot(df['CHEST PAIN'], shade=True, bw=1) 

plt.show()

# %%
sns.kdeplot(df['AGE'],df['CHRONIC DISEASE'], shade=True, bw=1) 

plt.show()

# %%
sns.jointplot(x="AGE", y="CHRONIC DISEASE", data=df)
plt.show()

# %%
sns.jointplot(x="AGE", y="SMOKING", data=df)
plt.show()

# %%
sns.scatterplot(x="AGE", y="SMOKING", data=df, size="GENDER",hue='Level')

plt.show()

# %%
sns.set_style("darkgrid")

sns.pairplot(df)

plt.show()

# %%
df.dtypes

# %%
#relplot()
#scatterplot()
#lineplot()
sns.relplot(data= df,x='AGE',y='SMOKING',hue='Level')

# %%
sns.stripplot(x="CHEST PAIN", y="WHEEZING", data=df)

plt.show()

# %%
sns.swarmplot(x="ALLERGY ", y="SWALLOWING DIFFICULTY", data=df)

plt.show()
# Out:
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(y=df["AGE"])

plt.show()

# %%
sns.boxplot(x="CHEST PAIN", y="AGE", data=df)

plt.show()

# %%
sns.violinplot(x=df["ANXIETY"])

plt.show()
