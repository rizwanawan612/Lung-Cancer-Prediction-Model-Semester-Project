# %% [markdown]
# # K Nearest Neighbors

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv("D:/survey lung cancer1.csv")

# %%
df.head(20)
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        1   69        1               2        2              1
# 1        1   74        2               1        1              1
# 2        0   59        1               1        1              2
# 3        1   63        2               2        2              1
# 4        0   63        1               2        1              1
# 5        0   75        1               2        1              1
# 6        1   52        2               1        1              1
# 7        0   51        2               2        2              2
# 8        0   68        2               1        2              1
# 9        1   53        2               2        2              2
# 10       0   61        2               2        2              2
# 11       1   72        1               1        1              1
# 12       0   60        2               1        1              1
# ...

# %% [markdown]
# ## Standardize the Variables

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('Level',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('Level',axis=1))

# %%
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#      GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  PEER_PRESSURE  \
# 0  0.952579  0.771850 -1.135292        0.869300  1.003241      -1.003241
# 1  0.952579  1.381829  0.880830       -1.150351 -0.996769      -1.003241
# 2 -1.049781 -0.448107 -1.135292       -1.150351 -0.996769       0.996769
# 3  0.952579  0.039876  0.880830        0.869300  1.003241      -1.003241
# 4 -1.049781  0.039876 -1.135292        0.869300 -0.996769      -1.003241
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0        -1.009756  0.696833 -1.120480  0.892475           0.892475  0.852207
# 1         0.990338  0.696833  0.892475 -1.120480          -1.120480 -1.173424
# 2        -1.009756  0.696833 -1.120480  0.892475          -1.120480  0.852207
# 3        -1.009756 -1.435063 -1.120480 -1.120480           0.892475 -1.173424
# 4        -1.009756 -1.435063 -1.120480  0.892475          -1.120480  0.852207
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# ...

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features,df['Level'],
                                                    test_size=0.30)

# %% [markdown]
# ## Using KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)
# Out:
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# ## Predictions and Evaluations
#
# Let's evaluate our KNN model!

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[ 5  4]
#  [ 4 80]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.95      0.95      0.95        84
#
#     accuracy                           0.91        93
#    macro avg       0.75      0.75      0.75        93
# weighted avg       0.91      0.91      0.91        93

# %% [markdown]
# ## Choosing a K Value
#
# Let's go ahead and use the elbow method to pick a good K Value:
# <br> Elbow Method in Supervised Machine Learning(Optimal K Value)
# Elbow method helps data scientists to select the optimal number of clusters for KNN clustering. It is one of the most popular methods to determine this optimal value of K

# %%
# https://towardsdatascience.com/cross-validation-using-knn-6babb6e619c8 
accuracy_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,df_feat,df['Level'],cv=10)
    accuracy_rate.append(score.mean())
# Out:
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# Here we can see that that after arouns K>23 the error rate just tends to hover around 0.06-0.05 Let's retrain the model with that and check the classification report!

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=1')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
print ('\nConfussion matrix:\n',confusion_matrix(y_test,pred))
# Out:
# WITH K=1
#
#
# [[ 5  4]
#  [ 4 80]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.95      0.95      0.95        84
#
#     accuracy                           0.91        93
#    macro avg       0.75      0.75      0.75        93
# weighted avg       0.91      0.91      0.91        93
#
#
# Confussion matrix:
#  [[ 5  4]
#  [ 4 80]]
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
# NOW WITH K=23
knn = KNeighborsClassifier(n_neighbors=23)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=23')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=23
#
#
# [[ 1  8]
#  [ 0 84]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20         9
#            1       0.91      1.00      0.95        84
#
#     accuracy                           0.91        93
#    macro avg       0.96      0.56      0.58        93
# weighted avg       0.92      0.91      0.88        93
# C:\Users\M.Rizwan\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
